# %% [markdown]
# # Homework 7, Part Two: A dataset about dogs.
#
# Data from [a FOIL request to New York City](https://www.muckrock.com/foi/new-york-city-17/pet-licensing-data-for-new-york-city-23826/)

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Read in the file `NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx` and look at the first five rows

# %%
df = pd.read_excel("NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx",na_values="Unknown",nrows=30000)

# %%
# !head -n5 NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx
# Out:
# xl/_rels/workbook.xml.rels �(����j�0���{-����ȹ�B�m�B^[&�$���}EBS�{1=�,����z�5��#u�)(�:��ε
# �v�7� ���u�*�`S]_�_�ל�����H�e+)�X4e>�K���As���A��nQ�y� �4��L���m}b7���w�o����7�:�P!9qa
# !�#]P6xl/workbook.xml�T�n�0��?�B�2-Y��
# /��65���-6\T��e�����q�K�^DI=�����Rp�jÔ��~��:T�2����7Ko�:�b�b�$��jܳ���^�ǍR�H3q3k�B�dT`�Q9���UZ`��!�k�S�QjGA�#��t��~��n�sE
# ��jP�d��I��Cڥ��0}-�ʨ��jH����"�oRN�[��]Sv��%�-�u86v�2KӉC���eH�"?/��`ЫX���Z;�k�^k�����!�i�,��3%-����[�dسL�(��Q0M�U��1|1�Yc�9����}W�$��(�Q+�A3��a�

# %%
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?
#
# If there are more than 30,000 rows in your dataset, go back and only read in the first 30,000.
#
# * *Tip: there's an option with `.read_csv` to only read in a certain number of rows*

# %% [raw]
# df.shape

# %%
df.shape
# Out:
# (30000, 15)

# %%
df.dtypes
# Out:
# Owner Zip Code                     int64
# Animal Name                       object
# Animal Gender                     object
# Primary Breed                     object
# Secondary Breed                   object
# Animal Dominant Color             object
# Animal Secondary Color            object
# Animal Third Color                object
# Animal Birth              datetime64[ns]
# Spayed or Neut                    object
# Guard or Trained                  object
# Vaccinated                        object
# Application Date          datetime64[ns]
# License Issued Date       datetime64[ns]
# License Expired Date      datetime64[ns]
# dtype: object

# %% [markdown]
# ## Describe the dataset in words. What is each row? List two column titles along with what each of those columns means.
#
# For example: “Each row is an animal in the zoo. `is_reptile` is whether the animal is a reptile or not”

# %%
#Each row includes the adopted dog's description. is_Spayed or Neut is whether the dog is spayed or neutered, or neither. is_Vaccinated is wether the dog is vaccinated or not.

# %% [markdown]
# # Your thoughts
#
# Think of four questions you could ask this dataset. **Don't ask them**, just write them down in the cell below. Feel free to use either Markdown or Python comments.

# %%
#Q1.What are the most popular guard/trained dog breeds?
#Q2.What gender do the unspayed/unneutered dogs tend to fall in?
#Q3.How many dogs were born in the month of July? 
#Q4.How many dogs are vaccinated vs. unvaccinated?

# %% [markdown]
# # Looking at some dogs

# %% [markdown]
# ## What are the most popular (primary) breeds of dogs? Graph the top 10.

# %%
df['Primary Breed'].value_counts().head(10)
# Out:
# Yorkshire Terrier                       1882
# Shih Tzu                                1760
# Chihuahua                               1535
# Maltese                                 1133
# Labrador Retriever                      1074
# American Pit Bull Terrier/Pit Bull       780
# Labrador Retriever Crossbreed            738
# American Pit Bull Mix / Pit Bull Mix     722
# Jack Russell Terrier                     553
# Beagle                                   546
# Name: Primary Breed, dtype: int64

# %%
df['Primary Breed'].value_counts().head(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## "Unknown" is a terrible breed! Graph the top 10 breeds that are NOT Unknown
#
# * *Tip: Maybe you want to go back to your `.read_csv` and use `na_values=`? Maybe not? Up to you!*

# %%
df['Primary Breed'].value_counts().head(10)
# Out:
# Yorkshire Terrier                       1882
# Shih Tzu                                1760
# Chihuahua                               1535
# Maltese                                 1133
# Labrador Retriever                      1074
# American Pit Bull Terrier/Pit Bull       780
# Labrador Retriever Crossbreed            738
# American Pit Bull Mix / Pit Bull Mix     722
# Jack Russell Terrier                     553
# Beagle                                   546
# Name: Primary Breed, dtype: int64

# %%
df['Primary Breed'].value_counts().head(10).sort_values(ascending=True).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## What are the most popular dog names?

# %%
df['Animal Name'].value_counts()
# Out:
# UNKNOWN          203
# Max              202
# Bella            193
# Charlie          172
# Lola             146
#                 ...
# Bluno              1
# DARBY              1
# CHARLEY VIVAR      1
# TINY               1
# Squeeze            1
# Name: Animal Name, Length: 13720, dtype: int64

# %% [markdown]
# ## Do any dogs have your name? How many dogs are named "Max," and how many are named "Maxwell"?

# %%
df[df['Animal Name'].str.contains("Teresa",na=False)]
# Out:
#       Owner Zip Code Animal Name Animal Gender               Primary Breed  \
# 7524           10024      Teresa             F  Staffordshire Bull Terrier
# 9968           11201      Teresa             F              Boston Terrier
#
#      Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 7524             NaN                 BLACK                  WHITE
# 9968             NaN               Brindle                  White
#
#      Animal Third Color Animal Birth Spayed or Neut Guard or Trained  \
# 7524                NaN   2013-06-01            Yes               No
# 9968                NaN   2010-09-01            Yes              NaN
#
#      Vaccinated        Application Date License Issued Date  \
# 7524        Yes 2015-05-15 09:37:08.763          2015-05-15
# 9968        Yes 2015-05-31 16:09:03.270          2015-05-31
#
#      License Expired Date
# 7524           2016-06-18
# 9968           2018-05-31

# %%
df[df['Animal Name'].str.contains("Max",na=False)]
# Out:
#        Owner Zip Code Animal Name Animal Gender  \
# 42              10023         Max             M
# 53              10029         Max             M
# 128             11218         Max             M
# 174             11361         Max             M
# 281             11222     Maximus             M
# ...               ...         ...           ...
# 29438           10030     Maxwell             M
# 29540           11214  Maximillan             M
# 29762           10306         Max             M
# 29887           10035         Max             M
# 29973           10306         Max             M
#
#                               Primary Breed  Secondary Breed  \
# 42                   Dachshund, Long Haired              NaN
# 53     American Pit Bull Mix / Pit Bull Mix              NaN
# 128                                     NaN      Maltese Mix
# 174                 West High White Terrier              NaN
# 281                   Dachshund Smooth Coat              NaN
# ...

# %%
Max_dogs=df[df['Animal Name'].str.contains("Max",na=False)]

# %%
Max_dogs['Animal Name'].value_counts()
# Out:
# Max              202
# Maximus           27
# Maxwell           11
# Maxi               8
# Maxie              7
#                 ...
# Max Rodriguez      1
# Maximillia         1
# Max Caminiti       1
# Buddy Max          1
# Maximillan         1
# Name: Animal Name, Length: 94, dtype: int64

# %% [markdown]
# ## What percentage of dogs are guard dogs?

# %%
df['Guard or Trained'].value_counts(normalize=True)*100
# Out:
# No     99.914254
# Yes     0.085746
# Name: Guard or Trained, dtype: float64

# %% [markdown]
# ## What are the actual numbers?

# %%
df['Guard or Trained'].value_counts()
# Out:
# No     19809
# Yes       17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## Wait... if you add that up, is it the same as your number of rows? Where are the other dogs???? How can we find them??????
#
# Use your `.head()` to think about it, then you'll do some magic with `.value_counts()`. Think about missing data!

# %%
# No, the number is not the same as the number of rows. There are missing data.
df['Guard or Trained'].head()
# Out:
# 0     No
# 1     No
# 2    NaN
# 3     No
# 4    NaN
# Name: Guard or Trained, dtype: object

# %%
df['Guard or Trained'].value_counts(dropna=False)
# Out:
# No     19809
# NaN    10174
# Yes       17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## Maybe fill in all of those empty "Guard or Trained" columns with "No"? Or as `NaN`?
#
# Can we make an assumption either way? Then check your result with another `.value_counts()`

# %%
df['Guard or Trained'].replace("", np.nan)
# Out:
# 0         No
# 1         No
# 2        NaN
# 3         No
# 4        NaN
#         ...
# 29995     No
# 29996     No
# 29997    NaN
# 29998     No
# 29999     No
# Name: Guard or Trained, Length: 30000, dtype: object

# %%
df['Guard or Trained'].value_counts(dropna=False)
# Out:
# No     19809
# NaN    10174
# Yes       17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## What are the top dog breeds for guard dogs?

# %%
df[df['Guard or Trained']=='Yes']
# Out:
#        Owner Zip Code                Animal Name Animal Gender  \
# 2363            10014                     Truman             M
# 2702            10014  Bojangles Swagu Rosenberg             M
# 2871            11361                    Dorofey             M
# 3065            10033                 CLARA                  F
# 3274            10301                        Mia             F
# 5231            11209                      Lilly             F
# 10082           10014                     Jasper             M
# 11897           10304                        Rox             M
# 11925           10308                   Princess             F
# 15044           10040                      Nicky             M
# 20543           11235                       graf             M
# 20851           11363                 WINSTON                M
# 26278           11211                      Urkan             M
# 27584           11336                        Teo             M
# ...

# %%
guard_dogs=df[df['Guard or Trained']=='Yes']

# %%
guard_dogs['Primary Breed'].value_counts()
# Out:
# German Shepherd Dog           3
# Poodle, Standard              1
# German Shepherd Crossbreed    1
# Labrador Retriever            1
# Doberman Pinscher             1
# Shih Tzu                      1
# Rottweiler                    1
# Golden Retriever              1
# Schnauzer, Miniature          1
# Yorkshire Terrier             1
# Name: Primary Breed, dtype: int64

# %% [markdown]
# ## Create a new column called "year" that is the dog's year of birth
#
# The `Animal Birth` column is a datetime, so you can get the year out of it with the code `df['Animal Birth'].apply(lambda birth: birth.year)`.

# %%
import datetime

# %%
df['year']=df['Animal Birth'].apply(lambda birth: birth.year)

# %%
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %% [markdown]
# ## Calculate a new column called “age” that shows approximately how old the dog is. How old are dogs on average?

# %%
df['age']=df['License Issued Date']-df['Animal Birth']

# %%
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %%
df.dtypes
# Out:
# Owner Zip Code                      int64
# Animal Name                        object
# Animal Gender                      object
# Primary Breed                      object
# Secondary Breed                    object
# Animal Dominant Color              object
# Animal Secondary Color             object
# Animal Third Color                 object
# Animal Birth               datetime64[ns]
# Spayed or Neut                     object
# Guard or Trained                   object
# Vaccinated                         object
# Application Date           datetime64[ns]
# License Issued Date        datetime64[ns]
# License Expired Date       datetime64[ns]
# year                                int64
# age                       timedelta64[ns]
# dtype: object

# %%
pd.to_datetime(df['age'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
# ----> 1 pd.to_datetime(df['age'])
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1051, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049         result = arg.map(cache_array)
#    1050     else:
# -> 1051         values = convert_listlike(arg._values, format)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:367, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     365 orig_arg = arg
#     366 try:
# ...

# %%
df['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [256], in <cell line: 1>()
# ...

# %% [markdown]
# # Joining data together

# %% [markdown]
# ## Which neighborhood does each dog live in?
#
# You also have a (terrible) list of NYC neighborhoods in `zipcodes-neighborhoods.csv`. Join these two datasets together, so we know what neighborhood each dog lives in. **Be sure to not read it in as `df`, or else you'll overwrite your dogs dataframe.**

# %%
neighborhood_df = pd.read_csv("zipcodes-neighborhoods.csv")

# %%
neighborhood_df.head()
# Out:
#              neighborhood    zip borough
# 0           Central Bronx  10453   Bronx
# 1           Central Bronx  10457   Bronx
# 2           Central Bronx  10460   Bronx
# 3  Bronx Park and Fordham  10458   Bronx
# 4  Bronx Park and Fordham  10467   Bronx

# %%
merged = df.merge(neighborhood_df, left_on=df['Owner Zip Code'], right_on='zip')
merged.head(5)
# Out:
#    Owner Zip Code Animal Name Animal Gender                     Primary Breed  \
# 0           10024   BLUE MACK             M                               NaN
# 1           10024       Louie             M                               NaN
# 2           10024       Tosha             F               Collie, Smooth Coat
# 3           10024     Poppett             F  Dachshund, Long Haired Miniature
# 4           10024      Harlen             M                               NaN
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1       Coonhound                 Black                  White
# 2             NaN            BLUE MERLE                  WHITE
# 3             NaN                 Black                  Brown
# 4     Plott Hound                 BLACK                    TAN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# ...

# %% [markdown]
# ## What is the most popular dog name in all parts of the Bronx? How about Brooklyn? The Upper East Side?
#
# You'll want to do these separately, and filter for each.

# %%
merged[merged['borough']=='Bronx']
# Out:
#        Owner Zip Code          Animal Name Animal Gender  \
# 597             10461         Indie Zephir             M
# 598             10461                 Nina             F
# 599             10461          spuds salzo             M
# 600             10461               Boomer             M
# 601             10461                 Taco             M
# ...               ...                  ...           ...
# 29113           10474              Sparkle             F
# 29114           10474                Chuck             M
# 29115           10474               Snopee             M
# 29116           10474                 Keys             M
# 29117           10474  Montana Monti Nash              M
#
#                             Primary Breed Secondary Breed  \
# 597                            Rottweiler             NaN
# 598                  Schnauzer, Miniature             NaN
# 599                               Bulldog             NaN
# ...

# %%
Bronx_dogs=merged[merged['borough']=='Bronx']

# %%
Bronx_dogs['Animal Name'].value_counts()
# Out:
# Bella                  22
# Max                    21
# Rocky                  20
# Princess               15
# Lucky                  15
#                        ..
# Henny                   1
# MAXX                    1
# Ginger Gaston           1
# Frisco Melendez         1
# Montana Monti Nash      1
# Name: Animal Name, Length: 2031, dtype: int64

# %%
merged[merged['borough']=='Brooklyn']
# Out:
#        Owner Zip Code Animal Name Animal Gender  \
# 2591            11232      muneca             F
# 2592            11232       Lucky             F
# 2593            11232       Tyson             M
# 2594            11232      Hitchi             M
# 2595            11232       Seven             F
# ...               ...         ...           ...
# 29373           11203     Justice             F
# 29374           11203      Brutis             M
# 29375           11203     Timothy             M
# 29376           11203       Gizmo             M
# 29377           11203         Zev             M
#
#                               Primary Breed Secondary Breed  \
# 2591                                 Beagle             NaN
# 2592                      Yorkshire Terrier             NaN
# 2593     American Pit Bull Terrier/Pit Bull             NaN
# 2594   American Pit Bull Mix / Pit Bull Mix             NaN
# 2595                    Rhodesian Ridgeback             NaN
# ...

# %%
Brooklyn_dogs=merged[merged['borough']=='Brooklyn']

# %%
Brooklyn_dogs['Animal Name'].value_counts()
# Out:
# Max            46
# unknown        45
# UNKNOWN        45
# Bella          45
# Charlie        42
#                ..
# GUINNESS        1
# Red Jupiter     1
# Becky           1
# Doug            1
# Zev             1
# Name: Animal Name, Length: 4538, dtype: int64

# %%
merged[merged['neighborhood']=='Upper East Side']
# Out:
#        Owner Zip Code Animal Name Animal Gender         Primary Breed  \
# 2153            10028        Lola             F               Maltese
# 2154            10028       ROSIE             F                   NaN
# 2155            10028        Rooz             M     Poodle, Miniature
# 2156            10028    ALISTAIR             M           Labradoodle
# 2157            10028       Roxie             F    Labrador Retriever
# ...               ...         ...           ...                   ...
# 24022           10075     Biscuit             M  Pembroke Welsh Corgi
# 24023           10075        LANA             F   Collie, Smooth Coat
# 24024           10075  MAX                    M             Chihuahua
# 24025           10075    Godzilla             M                   Pug
# 24026           10075       OLIVE             F  Portuguese Water Dog
#
#       Secondary Breed Animal Dominant Color Animal Secondary Color  \
# ...

# %%
UpperEastSide_dogs=merged[merged['borough']=='Bronx']

# %%
UpperEastSide_dogs['Animal Name'].value_counts()
# Out:
# Bella                  22
# Max                    21
# Rocky                  20
# Princess               15
# Lucky                  15
#                        ..
# Henny                   1
# MAXX                    1
# Ginger Gaston           1
# Frisco Melendez         1
# Montana Monti Nash      1
# Name: Animal Name, Length: 2031, dtype: int64

# %% [markdown]
# ## What is the most common dog breed in each of the neighborhoods of NYC?
#
# * *Tip: There are a few ways to do this, and some are awful (see the "top 5 breeds in each borough" question below).*

# %%
merged['Primary Breed'].describe()
# Out:
# count                 24859
# unique                  249
# top       Yorkshire Terrier
# freq                   1861
# Name: Primary Breed, dtype: object

# %%
merged.groupby(by='neighborhood')['Primary Breed'].value_counts()
# Out:
# neighborhood  Primary Breed
# Borough Park  Yorkshire Terrier              49
#               Maltese                        34
#               Shih Tzu                       34
#               Chihuahua                      32
#               Labrador Retriever             19
#                                              ..
# West Queens   Soft Coated Wheaten Terrier     1
#               Tibetan Spaniel                 1
#               Toy Fox Terrier                 1
#               Weimaraner                      1
#               Wire Fox Terrier                1
# Name: Primary Breed, Length: 3987, dtype: int64

# %% [markdown]
# ## What breed of dogs are the least likely to be spayed? Male or female?
#
# * *Tip: This has a handful of interpretations, and some are easier than others. Feel free to skip it if you can't figure it out to your satisfaction.*

# %%
merged['Spayed or Neut'].value_counts()
# Out:
# Yes    24300
# No      5273
# Name: Spayed or Neut, dtype: int64

# %%
merged['Spayed or Neut']=='No'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29568    False
# 29569    False
# 29570     True
# 29571    False
# 29572     True
# Name: Spayed or Neut, Length: 29573, dtype: bool

# %%
merged[merged['Spayed or Neut']=='No']
# Out:
#        Owner Zip Code             Animal Name Animal Gender  \
# 92              10024              Lil A                  M
# 113             10024  King George Fitzgerald             M
# 125             10024                     Sia             F
# 134             10024                Scarlett             F
# 142             10024                   Marzi             F
# ...               ...                     ...           ...
# 29561           11436                    Noah             M
# 29563           11436            Chanel Sirju             F
# 29565           11436                   Rocko             M
# 29570           11436                   marco             M
# 29572           11005                  Bichon             F
#
#                        Primary Breed Secondary Breed Animal Dominant Color  \
# 92                 Yorkshire Terrier             NaN                 BLACK
# 113    Cavalier King Charles Spaniel             NaN                 BLACK
# ...

# %%
Unspayed_dogs=merged[merged['Spayed or Neut']=='No']

# %%
Unspayed_dogs['Primary Breed'].value_counts()
# Out:
# Yorkshire Terrier                     531
# Shih Tzu                              401
# Chihuahua                             303
# Maltese                               300
# American Pit Bull Terrier/Pit Bull    173
#                                      ...
# Chesapeake Bay Retriever                1
# Australian Silky Terrier                1
# Afghan Hound                            1
# Belgian Sheepdog                        1
# Lakeland Terrier                        1
# Name: Primary Breed, Length: 190, dtype: int64

# %%
Unspayed_dogs['Animal Gender'].value_counts()
# Out:
# M    3343
# F    1930
# Name: Animal Gender, dtype: int64

# %% [markdown]
# ## Make a new column called `monochrome` that is True for any animal that only has black, white or grey as one of its colors. How many animals are monochrome?

# %%
merged['monochrome']=merged['Animal Dominant Color'].str.contains("BLACK") & merged['Animal Dominant Color'].str.contains("Black") & merged['Animal Dominant Color'].str.contains("White") & merged['Animal Dominant Color'].str.contains("WHITE") & merged['Animal Dominant Color'].str.contains("Gray") & merged['Animal Dominant Color'].str.contains("GRAY")

# %%
merged.head()
# Out:
#    Owner Zip Code Animal Name Animal Gender                     Primary Breed  \
# 0           10024   BLUE MACK             M                               NaN
# 1           10024       Louie             M                               NaN
# 2           10024       Tosha             F               Collie, Smooth Coat
# 3           10024     Poppett             F  Dachshund, Long Haired Miniature
# 4           10024      Harlen             M                               NaN
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1       Coonhound                 Black                  White
# 2             NaN            BLUE MERLE                  WHITE
# 3             NaN                 Black                  Brown
# 4     Plott Hound                 BLACK                    TAN
#
#   Animal Third Color Animal Birth Spayed or Neut  ... Vaccinated  \
# ...

# %% [markdown]
# ## How many dogs are in each borough? Plot it in a graph.

# %%
merged.groupby(by='borough')['Animal Name'].describe()
# Out:
#                count unique      top freq
# borough
# Bronx           2727   2031    Bella   22
# Brooklyn        7347   4538      Max   46
# Manhattan      10427   5883  UNKNOWN  107
# Queens          6108   3902      Max   50
# Staten Island   2708   1842      Max   27

# %%
merged.groupby(by='borough')['Animal Name'].count().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='borough'>

# %% [markdown]
# ## Which borough has the highest number of dogs per-capita?
#
# You’ll need to merge in `population_boro.csv`

# %%
# !ls
# Out:
# Dataset TWO - Dogs.ipynb
# NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx
# boro_population.csv
# zipcodes-neighborhoods.csv

# %%
population_df = pd.read_csv("boro_population.csv")

# %%
population_df.head()
# Out:
#          borough  population  area_sqmi
# 0      Manhattan     1644518         23
# 1          Bronx     1455444         42
# 2       Brooklyn     2636735         71
# 3         Queens     2339150        109
# 4  Staten Island      474558         59

# %%
merged2 = merged.merge(population_df, left_on=['borough'], right_on=['borough'])
merged2.head(5)
# Out:
#    Owner Zip Code Animal Name Animal Gender                     Primary Breed  \
# 0           10024   BLUE MACK             M                               NaN
# 1           10024       Louie             M                               NaN
# 2           10024       Tosha             F               Collie, Smooth Coat
# 3           10024     Poppett             F  Dachshund, Long Haired Miniature
# 4           10024      Harlen             M                               NaN
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1       Coonhound                 Black                  White
# 2             NaN            BLUE MERLE                  WHITE
# 3             NaN                 Black                  Brown
# 4     Plott Hound                 BLACK                    TAN
#
#   Animal Third Color Animal Birth Spayed or Neut  ... License Issued Date  \
# ...

# %% [markdown]
# ## Make a bar graph of the top 5 breeds in each borough.
#
# How do you groupby and then only take the top X number? You **really** should ask me, because it's kind of crazy.

# %%
merged2.groupby(by='borough')['Primary Breed'].value_counts().groupby(level=0).head(5)
# Out:
# borough        Primary Breed
# Bronx          Yorkshire Terrier                     250
#                Shih Tzu                              244
#                Chihuahua                             208
#                American Pit Bull Terrier/Pit Bull    181
#                Maltese                               139
# Brooklyn       Yorkshire Terrier                     501
#                Shih Tzu                              481
#                Chihuahua                             391
#                Labrador Retriever                    255
#                Maltese                               247
# Manhattan      Chihuahua                             511
#                Yorkshire Terrier                     505
#                Shih Tzu                              454
#                Labrador Retriever                    422
#                Maltese                               332
# Queens         Yorkshire Terrier                     434
# ...

# %%
merged2.groupby(by='borough')['Primary Breed'].value_counts().groupby(level=0).head(5).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='borough,Primary Breed'>
